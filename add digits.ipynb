# %%
def adddigits(num):
    lst=[int(i) for i in str(num)]
    add=sum(lst)

    if(add>9):
        return adddigits(add)
    else:
        return add
    print(lst,add)
num = 19
adddigits(num)
# Out:
# 1
