# %%
nums = [1,2,3,4,4,3,2,1]
n = 4
first_half=nums[:n]
second_half=nums[n:]

lst=[]
for j in range(n):
    lst.append(first_half[j])
    lst.append(second_half[j])
lst
# Out:
# [1, 4, 2, 3, 3, 2, 4, 1]
