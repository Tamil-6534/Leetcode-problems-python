# %%
nums =[7,1,5,4,3,4,6,0,9,5,8,2]
lst=[]
for i in range(len(nums)):
    for j in range(i+1,len(nums)):
        if(nums[i]==nums[j]):
            lst.append(nums[j])
removed_duplicate=list(set(lst))
removed_duplicate
# Out:
# [4, 5]
