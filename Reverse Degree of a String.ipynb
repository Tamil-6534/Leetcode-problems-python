# %%
'''s = "zaza"
splitted=[allow for allow in s]
splitted.insert(0,'0')
reversed_indexes=[]
alphabets=["0",'z', 'y', 'x', 'w', 'v', 'u', 't', 's', 'r', 'q', 'p', 'o', 'n', 'm', 'l', 'k', 'j', 'i', 'h', 'g', 'f', 'e', 'd', 'c', 'b', 'a' ]
for i in splitted:
    indx=alphabets.index(i)
    reversed_indexes.append(indx)
length=len(s)
final=[]
for j in range(1,length+1):
    sum= j * reversed_indexes[j]
    final.append(sum)
sumed=0
for k in final:
    sumed +=k
print(sumed)'''

s = "zaza"
splitted=[allow for allow in s]
splitted.insert(0,'0')
alphabets={"0":0,'z':1, 'y':2, 'x':3, 'w':4, 'v':5, 'u':6, 't':7, 's':8, 'r':9, 'q':10, 'p':11, 'o':12, 'n':13, 'm':14, 'l':15, 'k':16, 'j':17, 'i':18, 'h':19, 'g':20, 'f':21, 'e':22, 'd':23, 'c':24, 'b':25, 'a':26}
length=len(s)
index=[]
for i in splitted:
    index.append(alphabets[i])
final=[]
summed=0
for j in range(1,length+1):
     sum= j* index[j]
     summed = summed+sum
print(summed)
# Out:
# 160
