# %%
word1 = ["ab", "c"]
word2 = ["a", "bc"]
joined1=''.join(word1)
joined2=''.join(word2)
if(joined1==joined2):
    print(joined1,joined2)
    print(True)
elif(joined1!=joined2):
    print(joined1,joined2)
    print(False)
# Out:
# abc abc
# True
