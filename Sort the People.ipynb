# %%
names = ["Alice","Bob","Bob"]
heights = [155,185,150]
sortedd=sorted(heights,reverse=True)
lst=[names[heights.index(sortedd[i])] for i in range(len(sortedd) )]

print(lst)
# Out:
# ['Bob', 'Alice', 'Bob']
