# %%
sentences = ["alice and bob love leetcode", "i think so too", "this is great thanks very much"]
lst=[]
for i in sentences:
    splitted=i.split()
    length=len(splitted)
    lst.append(length)
print(max(lst))
# Out:
# 3
