# %%
import pandas as pd

# Create DataFrame directly from the table
products_df = pd.DataFrame({
    'product_id': [0, 1, 2, 3, 4],
    'low_fats': ['Y', 'Y', 'N', 'Y', 'N'],
    'recyclable': ['N', 'Y', 'Y', 'Y', 'N']
})

result=products_df[(products_df['low_fats']=='Y') & (products_df['recyclable'])]
result[products_df]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9044\4001476866.py in ?()
#       7     'recyclable': ['N', 'Y', 'Y', 'Y', 'N']
#       8 })
#       9
#      10 result=products_df[(products_df['low_fats']=='Y') & (products_df['recyclable'])]
# ---> 11 result[products_df]
#
# c:\Users\tk224\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4096             return self._getitem_slice(key)
#    4097
#    4098         # Do we have a (boolean) DataFrame?
#    4099         if isinstance(key, DataFrame):
# -> 4100             return self.where(key)
#    4101
#    4102         # Do we have a (boolean) 1d indexer?
#    4103         if com.is_bool_indexer(key):
#
# c:\Users\tk224\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
# ...
