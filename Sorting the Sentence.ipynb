# %%
s="lGaWqAkfVIFhqBzRs3 l2 bwKhelcNiyNBpjGUN1"

x = s.split()
dic = {}
for i in x :
    dic[i[-1]] = i[:-1]
print(' '.join([dic[j] for j in sorted(dic)]))
# Out:
# bwKhelcNiyNBpjGUN l lGaWqAkfVIFhqBzRs
