# %%
s = "codeleet"
indices = [4,5,6,7,0,2,1,3]
lst=[]


for i in range(len(s)):

    index=indices.index(i)
    lst.append(s[index])
joined=''.join(lst)
print(joined)
# Out:
# ['l', 'e', 'e', 't', 'c', 'o', 'd', 'e']
