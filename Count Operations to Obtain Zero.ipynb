# %%
num1 = 10
num2 = 10
count=0

for i in range(num2+num1):

    if(num2==0 or num1==0):
        break
    elif(num1<=num2):
        num2=num2-num1
    else:
        num1=num1-num2
    count+=1
count
# Out:
# 10 0
# 1
