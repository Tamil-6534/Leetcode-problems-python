# %%
address = "1.1.1.1"
lst=[]
f_bracket='['
b_bracket=']'
for i in address:
    if(i=="."):
        lst.append(f_bracket)
        lst.append(i)
        lst.append(b_bracket)
    elif(i!="."):
        lst.append(i)
final="".join(lst)
print(final)
# Out:
# 1[.]1[.]1[.]1
