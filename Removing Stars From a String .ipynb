# %%
s = "leet**cod*e"
stack=[]
length=len(s)
for i in range(length):
    stack.append(s[i])
    if(len(stack)>=2) and (stack[-1]=="*"):
            stack.pop(),stack.pop()
print(''.join(stack))
# Out:
# lecoe
